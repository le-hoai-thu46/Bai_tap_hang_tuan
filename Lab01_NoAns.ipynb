# %% [markdown]
# ### Bai 1: Nhap vao một số nguyên, in ra màn hình giá trị gấp đôi của nó

# %%
a = float(input())
a = a*2
print(a)
# Out:
# 12.0

# %% [markdown]
# ### Problem 2
# #### Write a function that computes (a - b) * c.

# %%
a,b,c=map(float,input().split())
x=(a-b)*c
print("kết quả:",x)
# Out:
# kết quả: -7.0

# %% [markdown]
# ### Problem 3
# #### Write a function that returns a + b + a * b.

# %%
a,b=map(float,input().split())
x=a+b+a*b
print("kết quả:",x)
# Out:
# kết quả: 34.0

# %% [markdown]
# ### Problem 4
# #### Write a function that returns the count of positive integers k such that 1 <= k < n and k > (n - 1) / 2. (Example: n=9 -> 4).

# %%
n=int(input())
count=(n-1)-(n-1)//2
print(count)
# Out:
# 4

# %% [markdown]
# ### Problem 6
# #### Write a function that computes the area of a triangle with side lengths a, b, c (use Heron's formula). Raise ValueError if the sides cannot form a triangle.

# %%
a=float(input())
b=float(input())
c=float(input())
if a>0 and b>0 and c>0:
    if a+b>c and a+c>b and b+c>a:
        p=(a+b+c)/2
        dtich=(p*(p-a)*(p-b)*(p-c))**0.5
        print(dtich)
    else:
        print('value error')
else:
    print('value error')
# Out:
# 0.0

# %% [markdown]
# ### Problem 7
# #### Write a function that returns True if a, b, c can be the side lengths of a triangle; otherwise return False.

# %%
a=float(input())
b=float(input())
c=float(input())
if a>0 and b>0 and c>0:
    if a+b>c and a+c>b and b+c>a:
        print('true')
    else:
        print('false')
else:
    print('false')
# Out:
# false

# %% [markdown]
# ### Problem 8
# #### Write a function that returns the character that is n positions after character x in the alphabet.
# #### Preserve case and wrap around within A..Z or a..z.

# %%
x=input('nhập một chữ cái:')
n=int(input('nhập số thứ tự chữ cái muốn:'))
if len(x)!=1 or not x.isalpha():
    print("không đúng, nhập lại:))")
else:
    base=ord('A')if x.isupper()else ord('a')
    offset=ord(x)-base
    shifted=(offset+n)%26
    kq=chr(base+shifted)
    print(kq)
# Out:
# không đúng, nhập lại:))

# %% [markdown]
# ### Problem 9
# #### Write a function that converts an uppercase letter to lowercase. If the input is not a single character, raise ValueError.

# %%
x=input('nhập một kí tự:')
if len(x)==1 and x.isupper():
    print('kí tự được chuyển in thường:',x.lower())
else:
    print('không đúng định dạng, nhập lại:')
# Out:
# kí tự được chuyển in thường: e

# %% [markdown]
# ### Problem 10
# #### Write a function that, given a lowercase letter, returns a string containing that letter repeated 10 times.

# %%
c=input('nhập một kí tự viết thường:')
s=''
for i in range(10):
    s=s+c
print(s)
# Out:
# yyyyyyyyyy

# %% [markdown]
# ### Problem 12
# #### Write a function that returns a right isosceles triangle of height n using '*'.
# #### Line i (1-indexed) has i '*', joined with newlines.
# #### Example with n = 4
# #### *
# #### **
# #### ***
# #### ****

# %%
h=int(input('nhập chiều cao tam giác:'))
kq=''
for i in range(1,h+1):
    kq+='*'*i
    if i<h:
        kq+='\n'
print(kq)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
